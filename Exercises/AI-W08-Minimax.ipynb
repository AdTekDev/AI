# %% [markdown]
# ## Cho đồ thị chuyển trạng thái và Score được tính
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Các kiểu dữ liệu

# %%
## C1

dtype01 = 
(
    (
        (
            (4,3,8),
            (2,1)
        ),
        (
            (4,2,3)
        ),
        (
            (6,4),
            (7),
            (5,2)
        )
    ),
    ## chưa nhập hết data cho hình Tree
    (
    )
)

# %%
## C2

dtype02 = = {
    "Root" : "Root",
    "Childs" : {
        "Root" : [ "2-1" , "2-2" ],
        "2-1" : [ "3-1.1", "3-1.2", "3-1.3" ],
        
        "3-1.1" : [ "4-1.1.1", "4-1.1.2" ],
        "4-1.1.1" : [4, 3, 8], 
        "4-1.1.2" : [2, 1],
        
        "3-1.2" : ["4-1.2.1"],
        "4-1.2.1" : [4, 2, 3],
        
        "3-1.3" : [ "4-1.3.1", "4-1.3.2", "4-1.3.3"],
        "4-1.3.1" : [6, 7],
        "4-1.3.2" : [7],
        "4-1.3.3" : [5, 2],
        
        ## chưa nhập hết data cho hình Tree
    }
}

# %%
## C3

dtype03 = {
    "Nodes": [ 0, 11, 12, 21, 22, 23, 24, 25, 26,
             301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312],
    "Root" : 0,
    "Childs": { 
        0: [11, 12],
        11: [21, 22, 23],
        12: [24, 25, 26],
        21: [301, 302],
        22: [303],
        23: [304, 305, 306],
        24: [307],
        25: [308, 309],
        26: [310, 311, 312],
    },
    "EndValues" : {
        301: [4, 3, 8],
        302: [2, 1],
        303: [4, 2, 3],
        304: [6, 7],
        305: [7],
        306: [5, 2],
        307: [1, 9, 0],
        308: [4, 3],
        309: [0],
        310: [2, 8, 4],
        311: [3, 7],
        312: [5, 4, 1],
    }
}

# %% [markdown]
# ## Code cho giải thuật MiniMax

# %%
## Khung CODE cho giải thuật (áp dụng cho C2, C3)

def   max(xnode):
  global mmTree
  if xnode in mmTree["Childs"]:
    print(xnode, " - Childs: ", mmTree["Childs"][xnode])
    ## code HERE .... call MIN 
    ## return MAX  
  elif xnode in mmTree["EndValues"]:
    print(xnode, " - Values: ", mmTree["EndValues"][xnode])
    ## code HERE .... FIND MAX  
    ## return MAX  
  else:
    print("ERROR !!!")

def   min(xnode):
  global mmTree
  if xnode in mmTree["Childs"]:
    print(xnode, " - Childs: ", mmTree["Childs"][xnode])
    ## code HERE .... call MAX 
    ## return MIN 
  elif xnode in mmTree["EndValues"]:
    print(xnode, " - Values: ", mmTree["EndValues"][xnode])
    ## code HERE .... FIND MIN 
    ## return MIN 
  else:
    print("ERROR !!!")

# %% [markdown]
# ## Thử chạy giải thuật đã viết

# %%
mmTree = dtype01
max(mmTree["Root"])
