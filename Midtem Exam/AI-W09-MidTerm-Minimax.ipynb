# %% [markdown]
# # Artificial Intelligence - MidTerms (2023.05.18)

# %% [markdown]
# ## Midterm Exam
#
# ### COURSE NAME	:   Artificial Intelligence
# ### COURSE CODE	:   AI417
# ### Class: AI 417DE01-0200 (1004) Artificial Intelligence
#
# - Duration: 1.5 hours.
# - Write your name, StudentID and code at the file
# - Submit your answer to HSU's mLearning - https://mlearning.hoasen.edu.vn/course/view.php?id=16983

# %% [markdown]
# Consider the following game tree:
#
# ![image.png](attachment:image.png)
#
# 1. (1 point) What is Player A's next move?
# 2. (1 point) Which nodes would not be visited if minimax pruning search is used?
# 3. (1 point) Convert data from the above graph into a specific data type chosen by the instructor.
# 4. (3 points) Implementing the Minimax algorithm in Python for search trees using the specified data type provided by the instructor.
# 5. (2 points) Each step of the algorithm should display the current node being evaluated, the evaluated scores at each node, and the chosen move at each level of the search tree.
# 6. (2 points) Correctness and efficiency of the Minimax algorithm implementation for search trees.

# %% [markdown]
# ## Student's INFORMATION:
# - Fullname:
# - ID:
# - Code:

# %% [markdown]
# ## Code - Type of Data

# %%
## Code A - Data Type A

## Example 

DataTypeA = \
(
    (
        (
            (4,3,8),
            (2,1)
        ),
        (
            (4,2,3)
        ),
        (
            (6,4),
            (7),
            (5,2)
        )
    ),
    ## chưa nhập hết data cho hình Tree
    (
    )
)

# %%
## Code B - Data Type B

## Example 

DataTypeB = {
    "Root" : "Root",
    "Childs" : {
        "Root" : [ "2-1" , "2-2" ],
        "2-1" : [ "3-1.1", "3-1.2", "3-1.3" ],
        
        "3-1.1" : [ "4-1.1.1", "4-1.1.2" ],
        "4-1.1.1" : [4, 3, 8], 
        "4-1.1.2" : [2, 1],
        
        "3-1.2" : ["4-1.2.1"],
        "4-1.2.1" : [4, 2, 3],
        
        "3-1.3" : [ "4-1.3.1", "4-1.3.2", "4-1.3.3"],
        "4-1.3.1" : [6, 7],
        "4-1.3.2" : [7],
        "4-1.3.3" : [5, 2],
        
        ## chưa nhập hết data cho hình Tree
    }
}

# %% [markdown]
# # Student's Solution !!!
